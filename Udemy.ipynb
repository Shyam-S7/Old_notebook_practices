# %%
import pandas as pd
df=pd.read_csv("/content/udemy_courses.csv",parse_dates=["published_timestamp"])
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %% [markdown]
# published_timestamp change from obj to int  by parse_date

# %%
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull (). sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
dup=df.duplicated().sum()
dup
# Out:
# 6

# %%
dup=df.duplicated().any()
dup
# Out:
# True

# %%
df=df.drop_duplicates()

# %%
dup=df.duplicated().sum()
dup
# Out:
# 0

# %%
df.groupby ("subject") ["course_title"].sum()
#mine wrong
# Out:
# subject
# Business Finance       Ultimate Investment Banking CourseComplete GST...
# Graphic Design         Anatomy and Figure Drawing for BeginnersIllust...
# Musical Instruments    7 Ways A Beginner Guitarist Can Sound Better, ...
# Web Development        Learn Web Designing & HTML5/CSS3 Essentials in...
# Name: course_title, dtype: object

# %%
df["subject"].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
df["level"].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %% [markdown]
# Cnt of free and paid course

# %%
df["is_paid"].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %% [markdown]
# Which course more pictures  free or paid

# %%
df[df["num_lectures"]==df["num_lectures"].max()]["is_paid"].value_counts()
# Out:
# is_paid
# True    1
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(df["subject"])
# Out:
# <Axes: xlabel='count', ylabel='subject'>

# %% [markdown]
# For which ldve course provide

# %%
df["level"].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(df["level"])
# Out:
# <Axes: xlabel='count', ylabel='level'>

# %%
df[df.["is_paid"]].mean()
# Out:
#   File "<ipython-input-20-0a0e61d67690>", line 1
#     df[df.["is_paid"]].mean()
#           ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-534f4f3c80b7> in <cell line: 0>()
#       1 import seaborn as sns
# ----> 2 sns.heatmap(df.corr())
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
df["is_paid"].replace({"True":"1", "False":0})
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3673    True
# 3674    True
# 3675    True
# 3676    True
# 3677    True
# Name: is_paid, Length: 3672, dtype: bool

# %%
df.isin([95]).sum()
# Out:
# course_id                0
# course_title             0
# url                      0
# is_paid                  0
# price                  152
# num_subscribers          3
# num_reviews             10
# num_lectures             4
# level                    0
# content_duration         0
# published_timestamp      0
# subject                  0
# dtype: int64

# %%
a=df.sample(frac=0.2,random_state=42)
a
# Out:
#       course_id                                       course_title  \
# 2159      26648  Play Guitar and Understand Music Quick & Easy ...
# 2746    1121580  WordPress Blog : Create a WordPress Website fo...
# 1637    1076222           The most popular techniques in Photoshop
# 2008     476988                Guitar - Blues Guitar for Beginners
# 3254     705264                            Modern React with Redux
# ...         ...                                                ...
# 2072    1037868  Digital Pianist Course-Learn Piano & Keyboard ...
# 25       383414  Beginner to Pro in PowerPoint: Complete PowerP...
# 1568     518188            An Easy Introduction to Adobe Photoshop
# 679      173462  Aprende a invertir y deja que tu dinero trabaj...
# 1000     619786  Profit During Crashing Markets: A Step-by-Step...
#
#                                                     url  is_paid  price  \
# 2159  https://www.udemy.com/how-to-play-guitar-reall...     True     20
# ...

# %%
a.shape
# Out:
# (734, 12)

# %%
df["num_subscribers"].nsmallest(76)
# Out:
# 453    0
# 454    0
# 455    0
# 456    0
# 457    0
#       ..
# 523    1
# 574    1
# 584    1
# 638    1
# 780    1
# Name: num_subscribers, Length: 76, dtype: int64

# %%
df["num_subscribers"].value_counts()
# Out:
# num_subscribers
# 0       65
# 1       49
# 5       28
# 2       27
# 3       26
#         ..
# 6428     1
# 4449     1
# 6039     1
# 1522     1
# 901      1
# Name: count, Length: 2197, dtype: int64

# %%
aa=df.head(10)
aa
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
labels=["Apple", "banana", "Carrot"]
pd.cut(df["num_reviews"], bins=[50,100,150,200],labels=labels)
# Out:
# 0          NaN
# 1          NaN
# 2        Apple
# 3          NaN
# 4          NaN
#          ...
# 3673       NaN
# 3674       NaN
# 3675    Carrot
# 3676       NaN
# 3677       NaN
# Name: num_reviews, Length: 3672, dtype: category
# Categories (3, object): ['Apple' < 'banana' < 'Carrot']

# %%
aa.stack(left="num_reviews"
# Out:
# course_id  0             1070968
#            1             1113822
#            2             1006314
#            3             1210588
#            4             1011058
#                       ...
# subject    5    Business Finance
#            6    Business Finance
#            7    Business Finance
#            8    Business Finance
#            9    Business Finance
# Length: 120, dtype: object
