# %%
import pandas as pd
df=pd.read_csv("/content/adult.csv")
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
# Univariaent analysis

# %%
df["age"].describe()
# Out:
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
#distribution
df["age"].hist()
# Out:
# <Axes: >

# %%
#total no of person between 17 to 48
sum((df["age"]>=17) & (df["age"]<=48))
# Out:
# 37321

# %%
sum(df["age"].between(17, 48))
# Out:
# 37321

# %%
#distribution
df['workclass'].describe()
# Out:
# count       48842
# unique          9
# top       Private
# freq        33906
# Name: workclass, dtype: object

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
df['workclass'].hist()
# Out:
# <Axes: >

# %%
#no ug , pg
f1=df["education"]=="Bachelors"
f2=df["education"]=="Masters"

# %%
len(df[f1|f2])
# Out:
# 10682

# %%
sum(df["education"].isin(["Bachelors","Masters"]))
# Out:
# 10682

# %% [markdown]
# Bivarint

# %%
import seaborn as sns
sns.boxplot(x='income', y='age', data=df)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# Replace

# %%
def salary(sal) :
     if sal== "<=50K":
          return 0
     else:
          return 1

# %%
df["salary"]=df["income"].apply(salary)
df. head(1)
# Out:
#    age workclass  fnlwgt education  educational-num marital-status  \
# 0   25   Private  226802      11th                7  Never-married
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
#
#    hours-per-week native-country income  salary
# 0              40  United-States  <=50K       0

# %%
sns.splot(df["salary"])
# Out:
# <Axes: ylabel='salary'>
