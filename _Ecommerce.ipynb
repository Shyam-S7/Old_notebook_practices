# %%
import pandas as pd
df=pd.read_csv("/content/Ecommerce Purchases")
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df.iat[1,4]
# Out:
# 'Fletcher, Richards and Whitaker'

# %%
(df["Job"]=="Engineer"). sum()
#mine wrong
# Out:
# 0

# %% [markdown]
# Job title contain engineer

# %%
len(df[df["Job"].str.contains("engineer",case=False)])
# Out:
# 984

# %% [markdown]
# Find email of person with the ip 132.207.160.22

# %%
df[df["IP Address"]=="132.207.160.22"]["Email"]
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# How many people have Master card as their  credit card provider and made purchase above 50

# %%
df. columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df["CC Provider"]
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: CC Provider, Length: 10000, dtype: object

# %%
len(df[(df["CC Provider"]=="Mastercard") &(df["Purchase Price"]>50)])
# Out:
# 405

# %%
df[(df["CC Provider"]=="Mastercard")
 &(df["Purchase Price"]>50)].count()
# Out:
# Address             405
# Lot                 405
# AM or PM            405
# Browser Info        405
# Company             405
# Credit Card         405
# CC Exp Date         405
# CC Security Code    405
# CC Provider         405
# Email               405
# Job                 405
# IP Address          405
# Language            405
# Purchase Price      405
# dtype: int64

# %% [markdown]
# Find email of person credit no 4664825258997302

# %%
df[df["Credit Card"]==4664825258997302]["Email"]
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %% [markdown]
# how many people purchase am, pm

# %%
a=len(df[df['AM or PM']=="AM"]["Email"])
a  #AM
# Out:
# 4932

# %%
T=len(df['AM or PM'])
T
# Out:
# 10000

# %%
Pm=T-a
Pm   #PM
# Out:
# 5068

# %%
df['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# How many people credit card expires in 2020

# %%
df["CC Exp Date"].spilt("/")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0f4447009d9f> in <cell line: 0>()
# ----> 1 df["CC Exp Date"].spilt("/")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'spilt'

# %%
def f():
    c=0
    for i in df["CC Exp Date"]:

       # print (i.split("/")[1])
         s=i.split("/")[1]
         for a in s:
             if a==20:
                c=c+1

         print(c)

f()
#mine wrong

# %%
def f() :
     c=0
     for i in df["CC Exp Date"]:
         if i.split("/")[1]=='20':
            c=c+1
     print(c)


f()

# %%
len(df[df["CC Exp Date"].apply(lambda x:x[3:]=="20")])

#slice because 20/20  01234 it it's last 2 index

# %% [markdown]
# Top 5 most popular email provider (gmail.com yahho.com)

# %%
def s():
    for i in df["Email"]:
       S=i.split("@")[1]
       print(S)
      # l=[]

      # l.append(S)
      # print(list(l))
#valuecount to find most
s()#Mine

# %%
ls=[]
for i in df["Email"]:
      ls.append(i.split("@")[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2ded89ffd1e3> in <cell line: 0>()
#       1 ls=[]
# ----> 2 for i in df["Email"]:
#       3       ls.append(i.split("@")[1])
#
# NameError: name 'df' is not defined

# %%
df["temp"]=ls
df. head()

# %%
df["temp"].value_counts().head()

# %%
df["Email"].apply(lambda x:x.split("@") [1]).value_counts().head(5)

# %%
L=df.nlargest(5,"Job")
L.head()
