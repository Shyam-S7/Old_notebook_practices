# %%
import pandas as pd
df=pd.read_excel("/content/Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         21 non-null     int64
#  1   First_Name         21 non-null     object
#  2   Last_Name          20 non-null     object
#  3   Phone_Number       19 non-null     object
#  4   Address            21 non-null     object
#  5   Paying Customer    21 non-null     object
#  6   Do_Not_Contact     17 non-null     object
#  7   Not_Useful_Column  21 non-null     bool
# dtypes: bool(1), int64(1), object(6)
# memory usage: 1.3+ KB

# %%
df.shape
# Out:
# (21, 8)

# %%
#df["Last_Name"]=df["Last_Name"].str.lstrip("/,...").str.rstrip("_")
#df["Last_Name"]

# %%
import numpy as np

# %%
df["Last_Name"]=df["Last_Name"].str.strip("/,...,_")
df["Last_Name"]
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# 20     Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"]=df["Last_Name"].replace({np.NaN:"Kumar"})
df["Last_Name"]
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8          Kumar
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# 20     Skywalker
# Name: Last_Name, dtype: object

# %%
full=df["First_Name"]+" "+df[ "Last_Name"]

# %%
df.insert(loc=3,column="Full_name", value=full)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-c076422fe6fb> in <cell line: 0>()
# ----> 1 df.insert(loc=3,column="Full_name", value=full)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#
# ValueError: cannot insert Full_name, already exists

# %%
df
# Out:
#     CustomerID First_Name   Last_Name         Full_name  Phone_Number  \
# 0         1001      Frodo     Baggins     Frodo Baggins  123-545-5421
# 1         1002       Abed       Nadir        Abed Nadir  123/643/9775
# 2         1003     Walter       White     Walter /White    7066950392
# 3         1004     Dwight     Schrute    Dwight Schrute  123-543-2345
# 4         1005        Jon        Snow          Jon Snow  876|678|3469
# 5         1006        Ron     Swanson       Ron Swanson  304-762-2467
# 6         1007       Jeff      Winger     Jeff   Winger           NaN
# 7         1008   Sherlock      Holmes   Sherlock Holmes  876|678|3469
# 8         1009    Gandalf       Kumar               NaN           N/a
# 9         1010      Peter      Parker      Peter Parker  123-545-5421
# 10        1011    Samwise      Gamgee    Samwise Gamgee           NaN
# 11        1012      Harry      Potter   Harry ...Potter    7066950392
# ...

# %%
df["Phone_Number"].str.replace({"-,|,/":" "})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-1b61fd8bad3b> in <cell line: 0>()
# ----> 1 df["Phone_Number"].str.replace({"-,|,/":" "})
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     135                 )
#     136                 raise TypeError(msg)
# --> 137             return func(self, *args, **kwargs)
#     138
#     139         wrapper.__name__ = func_name
#
# TypeError: StringMethods.replace() missing 1 required positional argument: 'repl'

# %%
df["city"]=df["Address"].str.split(",").str[1]
df["city"]
# Out:
# 0             Shire
# 1               NaN
# 2               NaN
# 3      Pennsylvania
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9          New York
# 10            Shire
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16     Pennsylvania
# 17              NaN
# 18              NaN
# 19         Tatooine
# 20         Tatooine
# Name: city, dtype: object

# %% [markdown]
# Use. Str [0]  index

# %%
pd.to_csv(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-a1bb17aa7cca> in <cell line: 0>()
# ----> 1 pd.to_csv(df)
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
l=[]
for i in df["Address"]:
     i.append(i.split(",")[0])
     print(l)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-79bfd7e9aabc> in <cell line: 0>()
#       1 l=[]
#       2 for i in df["Address"]:
# ----> 3      i.append(i.split(",")[0])
#       4      print(l)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace(r"-,|,/", "",regex=True)
df["Phone_Number"]
# Out:
# 0     123 545 5421
# 1     123 643 9775
# 2              NaN
# 3     123 543 2345
# 4     876 678 3469
# 5     304 762 2467
# 6              NaN
# 7     876 678 3469
# 8              N a
# 9     123 545 5421
# 10             NaN
# 11             NaN
# 12    123 543 2345
# 13    876 678 3469
# 14    304 762 2467
# 15    123 545 5421
# 16    123 643 9775
# 17             NaN
# 18             N a
# 19    876 678 3469
# 20    876 678 3469
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace(r"[-|/]", " ", regex=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name         Full_name  Phone_Number  \
# 0         1001      Frodo     Baggins     Frodo Baggins  123 545 5421
# 1         1002       Abed       Nadir        Abed Nadir  123 643 9775
# 2         1003     Walter       White     Walter /White           NaN
# 3         1004     Dwight     Schrute    Dwight Schrute  123 543 2345
# 4         1005        Jon        Snow          Jon Snow  876 678 3469
# 5         1006        Ron     Swanson       Ron Swanson  304 762 2467
# 6         1007       Jeff      Winger     Jeff   Winger           NaN
# 7         1008   Sherlock      Holmes   Sherlock Holmes  876 678 3469
# 8         1009    Gandalf       Kumar               NaN           N a
# 9         1010      Peter      Parker      Peter Parker  123 545 5421
# 10        1011    Samwise      Gamgee    Samwise Gamgee           NaN
# 11        1012      Harry      Potter   Harry ...Potter           NaN
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            1
# Phone_Number         2
# Address              0
# Paying Customer      0
# Do_Not_Contact       4
# Not_Useful_Column    0
# dtype: int64

# %%
df["Phone_Number"].str.replace(r"[^a-zA-Z0-9]", "", regex=True)
# Out:
# 0     1235455421
# 1     1236439775
# 2            NaN
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            NaN
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           NaN
# 11           NaN
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           NaN
# 18            Na
# 19    8766783469
# 20    8766783469
# Name: Phone_Number, dtype: object

# %%
import re
st="My name is #@shyam@(+#"
pat=r"[^#@]"
res=re.search(pat,st)
print(res)
# Out:
# <re.Match object; span=(0, 1), match='M'>

# %%
"Hello, my name is Shyam! You can contact me at shyam_123@gmail.com for any queries. I was born on 12/05/2002 and my backup email is shyam.work@outlook.com. Please avoid sending messages to test@xyz!com. Let’s meet on 26-02-2025. Also, my Twitter handle is @Shyam_Dev!"
# Out:
# 'Hello, my name is Shyam! You can contact me at shyam_123@gmail.com for any queries. I was born on 12/05/2002 and my backup email is shyam.work@outlook.com. Please avoid sending messages to test@xyz!com. Let’s meet on 26-02-2025. Also, my Twitter handle is @Shyam_Dev!'

# %%
import re
text = "The rain@ in Spain."
pattern = r"@"
result = re.search(pattern, text)
if result:
    print("Match found:", result.group())
else:
    print("No match found.")
# Out:
# Match found: @

# %%
df = pd.DataFrame({'text': ['Hello abc@gmail.com', 'Contact xyz123@yahoo.com']})
df['emails'] = df['text'].str.extract(r'([\w\.-]+@[\w\.-]+\.\w+)')
df

# %%
df = pd.DataFrame({'text': ['Hello abc@gmail.com', 'Contact xyz123@yahoo.com']})
df['emails'] = df['text'].str.extract(r'([\w\.-]+@[\w\.-]+\.\w+)')
df

# %%
import pandas as pd

# Example DataFrame
df = pd.DataFrame({
    'column_name': ['abc@123', 'def$456', 'ghi!789']
})

# Remove special characters
df['column_name'] = df['column_name'].str.replace(r'[^a-zA-Z0-9]', '', regex=True)

print(df)
