# %%
import pandas as pd
df=pd.read_excel("car.xlsx")
print(df)
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 0     29  p  compact
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0       displ         year         cyl         cty         hwy
# count  234.000000  234.000000   234.000000  234.000000  234.000000  234.000000
# mean   117.500000    3.471795  2003.500000    5.888889   16.858974   23.440171
# std     67.694165    1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.000000    1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%     59.250000    2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%    117.500000    3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%    175.750000    4.600000  2008.000000    8.000000   19.000000   27.000000
# max    234.000000    7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
df.head(10)
# Out:
#    Unnamed: 0 manufacturer       model  displ  year  cyl       trans drv  cty  \
# 0           1         audi          a4    1.8  1999    4    auto(l5)   f   18
# 1           2         audi          a4    1.8  1999    4  manual(m5)   f   21
# 2           3         audi          a4    2.0  2008    4  manual(m6)   f   20
# 3           4         audi          a4    2.0  2008    4    auto(av)   f   21
# 4           5         audi          a4    2.8  1999    6    auto(l5)   f   16
# 5           6         audi          a4    2.8  1999    6  manual(m5)   f   18
# 6           7         audi          a4    3.1  2008    6    auto(av)   f   18
# 7           8         audi  a4 quattro    1.8  1999    4  manual(m5)   4   18
# 8           9         audi  a4 quattro    1.8  1999    4    auto(l5)   4   16
# 9          10         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20
#
#    hwy fl    class
# 0   29  p  compact
# 1   29  p  compact
# 2   31  p  compact
# 3   30  p  compact
# ...

# %%
df.tail(20)
# Out:
#      Unnamed: 0 manufacturer       model  displ  year  cyl       trans drv  \
# 214         215   volkswagen       jetta    2.0  1999    4    auto(l4)   f
# 215         216   volkswagen       jetta    2.0  2008    4    auto(s6)   f
# 216         217   volkswagen       jetta    2.0  2008    4  manual(m6)   f
# 217         218   volkswagen       jetta    2.5  2008    5    auto(s6)   f
# 218         219   volkswagen       jetta    2.5  2008    5  manual(m5)   f
# 219         220   volkswagen       jetta    2.8  1999    6    auto(l4)   f
# 220         221   volkswagen       jetta    2.8  1999    6  manual(m5)   f
# 221         222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f
# 222         223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f
# 223         224   volkswagen  new beetle    2.0  1999    4  manual(m5)   f
# 224         225   volkswagen  new beetle    2.0  1999    4    auto(l4)   f
# ...

# %%
df
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 0     29  p  compact
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'manufacturer', 'model', 'displ', 'year', 'cyl', 'trans',
#        'drv', 'cty', 'hwy', 'fl', 'class'],
#       dtype='object')

# %%
print(df[["model","manufacturer"]])
# Out:
#       model manufacturer
# 0        a4         audi
# 1        a4         audi
# 2        a4         audi
# 3        a4         audi
# 4        a4         audi
# ..      ...          ...
# 229  passat   volkswagen
# 230  passat   volkswagen
# 231  passat   volkswagen
# 232  passat   volkswagen
# 233  passat   volkswagen
#
# [234 rows x 2 columns]

# %%
df.rename(columns={"cty":"city"},inplace=True)
df
# Out:
#      Unnamed: 0 manufacturer   model  display  year  cyl       trans drv  \
# 0             1         audi      a4      1.8  1999    4    auto(l5)   f
# 1             2         audi      a4      1.8  1999    4  manual(m5)   f
# 2             3         audi      a4      2.0  2008    4  manual(m6)   f
# 3             4         audi      a4      2.0  2008    4    auto(av)   f
# 4             5         audi      a4      2.8  1999    6    auto(l5)   f
# ..          ...          ...     ...      ...   ...  ...         ...  ..
# 229         230   volkswagen  passat      2.0  2008    4    auto(s6)   f
# 230         231   volkswagen  passat      2.0  2008    4  manual(m6)   f
# 231         232   volkswagen  passat      2.8  1999    6    auto(l5)   f
# 232         233   volkswagen  passat      2.8  1999    6  manual(m5)   f
# 233         234   volkswagen  passat      3.6  2008    6    auto(s6)   f
#
#      city  hwy fl    class
# 0      18   29  p  compact
# 1      21   29  p  compact
# ...

# %%
df.drop(columns={"class"},inplace=True)
df
# Out:
#      Unnamed: 0 manufacturer   model  display  year  cyl       trans drv  \
# 0             1         audi      a4      1.8  1999    4    auto(l5)   f
# 1             2         audi      a4      1.8  1999    4  manual(m5)   f
# 2             3         audi      a4      2.0  2008    4  manual(m6)   f
# 3             4         audi      a4      2.0  2008    4    auto(av)   f
# 4             5         audi      a4      2.8  1999    6    auto(l5)   f
# ..          ...          ...     ...      ...   ...  ...         ...  ..
# 229         230   volkswagen  passat      2.0  2008    4    auto(s6)   f
# 230         231   volkswagen  passat      2.0  2008    4  manual(m6)   f
# 231         232   volkswagen  passat      2.8  1999    6    auto(l5)   f
# 232         233   volkswagen  passat      2.8  1999    6  manual(m5)   f
# 233         234   volkswagen  passat      3.6  2008    6    auto(s6)   f
#
#      city  hwy fl
# 0      18   29  p
# 1      21   29  p
# 2      20   31  p
# ...

# %%
df = df.loc[:, ['class']]
print(df)
# Out:
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 1 columns]

# %%
int=df.select_dtypes(include=['int64'])
float = df.select_dtypes(include=['float64'])

print("Max values:", int.max(),float.max())
print("Min values:", int.min(),float.min())

#mean overall records
D=df.select_dtypes(include=['int64', 'float64']).mean().mean()
print("Overall Mean:",D)
# Out:
# Max values: Unnamed: 0     234
# year          2008
# cyl              8
# cty             35
# hwy             44
# dtype: int64 displ    7.0
# dtype: float64
# Min values: Unnamed: 0       1
# year          1999
# cyl              4
# cty              9
# hwy             12
# dtype: int64 displ    1.6
# dtype: float64
# Overall Mean: 361.7766381766381

# %%
#horizontal and vertical slicing
#print(df[0:4])
#print (df[["class", "cty"]])
print(df.loc[0:4,["cty","drv"]])
# Out:
#    cty drv
# 0   18   f
# 1   21   f
# 2   20   f
# 3   21   f
# 4   16   f

# %%
# Countof 'compact' in the 'class' column
count = df['class'].value_counts()['compact']

print("Count:",count)
# Out:
# Count: 47

# %%
#Average
df.select_dtypes(include=['int64', 'float64']).mean()
# Out:
# Unnamed: 0     117.500000
# displ            3.471795
# year          2003.500000
# cyl              5.888889
# cty             16.858974
# hwy             23.440171
# dtype: float64

# %%
df.isna().any()
#no null values, so no need to replace
# Out:
# Unnamed: 0      False
# manufacturer    False
# model           False
# displ           False
# year            False
# cyl             False
# trans           False
# drv             False
# cty             False
# hwy             False
# fl              False
# class           False
# dtype: bool

# %%
non_numeric= df.select_dtypes(exclude=['int64', 'float64']).columns

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df[col]=df[col].astype(str)
for col in non_numeric:
    df[col] = le.fit_transform(df[col])
df
# Out:
#      Unnamed: 0  manufacturer  model  displ  year  cyl  trans  drv  cty  hwy  \
# 0             1             0      1    1.8  1999    4      3    1   18   29
# 1             2             0      1    1.8  1999    4      8    1   21   29
# 2             3             0      1    2.0  2008    4      9    1   20   31
# 3             4             0      1    2.0  2008    4      0    1   21   30
# 4             5             0      1    2.8  1999    6      3    1   16   26
# ..          ...           ...    ...    ...   ...  ...    ...  ...  ...  ...
# 229         230            14     31    2.0  2008    4      7    1   19   28
# 230         231            14     31    2.0  2008    4      9    1   21   29
# 231         232            14     31    2.8  1999    6      3    1   16   26
# 232         233            14     31    2.8  1999    6      8    1   18   26
# 233         234            14     31    3.6  2008    6      7    1   17   26
#
#      fl class
# 0     3     1
# ...
